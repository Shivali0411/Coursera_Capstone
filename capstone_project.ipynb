# %%
This notebook is to be used for the coursera capstone proejct

# %%
conda create -n name_of_my_env python
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.2
#   latest version: 4.8.3
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /srv/conda/envs/name_of_my_env
#
#   added / updated specs:
#     - python
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _libgcc_mutex-0.1          |      conda_forge           3 KB  conda-forge
#     _openmp_mutex-4.5          |            0_gnu         435 KB  conda-forge
#     ca-certificates-2020.6.20  |       hecda079_0         145 KB  conda-forge
#     certifi-2020.6.20          |   py38h32f6830_0         151 KB  conda-forge
#     ld_impl_linux-64-2.34      |       h53a641e_5         616 KB  conda-forge
#     libffi-3.2.1               |    he1b5a44_1007          47 KB  conda-forge
# ...

# %%
activate name_of_my_env

# %%
conda install pandas

# %%
import panda as pd

# %%
import numpy as np

# %%
print "Hello Capstone Project Course!"
